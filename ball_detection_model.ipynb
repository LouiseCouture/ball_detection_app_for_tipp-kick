# %%
import cv2
import numpy as np
import torch
# import tensorflow as tf
# from tensorflow import keras


def detect_ball(model, frame: np.ndarray):
    WIDTH = 360
    HEIGHT = 360
    resized_frame = cv2.resize(frame, (WIDTH, HEIGHT))
    detection = model(resized_frame)
    bounding_box = detection.xyxy[0].numpy()

    for box in bounding_box:
        if box[5] == 0:
            x = box[0] + (box[2] - box[0]) / 2
            y = box[1] + (box[3] - box[1]) / 2
            return (int(x), int(y)), (box[0], box[1], box[2], box[3])
            # array([     124.15,         179,      130.78,      185.98,      0.8651,           0], dtype=float32)
            # box[0]:   Left
            # box[1]:   Top
            # box[2]:   Right
            # box[3]:   Bottom
            # box[4]:   Probability
            # box[5]:   Klasse 0 = Ball

    return False, False

# Load model 
ball_model = torch.hub.load('ultralytics/yolov5', 'custom', path='03_Ball_Detection/models/ball_weights_V2.pt', force_reload=False)

def detect_ball_static(image,model=ball_model):

    height, width, _ = image.shape

    # start object detection
    # ball detection returns center coordinates from the ball
    ball_center, ball_bb = detect_ball(model, image)
    if ball_center:  
        ball_center = [ball_center[0] * (width / 360), ball_center[1] * (height / 360)] 
        ball_bb=[int(ball_bb[0]* (width / 360)),
                int(ball_bb[1]* (height / 360)),
                int(ball_bb[2]* (width / 360)),
                int(ball_bb[3]* (height / 360))]  
        
        return [ball_bb[0],ball_bb[1],ball_bb[2]-ball_bb[0]+10,ball_bb[3]-ball_bb[1]+10]
    return None
# Out:
# c:\Users\lc100\AppData\Local\miniconda3\envs\frameSubtraction\Lib\site-packages\numpy\_distributor_init.py:30: UserWarning: loaded more than 1 DLL from .libs:
# c:\Users\lc100\AppData\Local\miniconda3\envs\frameSubtraction\Lib\site-packages\numpy\.libs\libopenblas.FB5AE2TYXYH2IJRDKGDGQ3XBKLKTF43H.gfortran-win_amd64.dll
# c:\Users\lc100\AppData\Local\miniconda3\envs\frameSubtraction\Lib\site-packages\numpy\.libs\libopenblas64__v0.3.21-gcc_10_3_0.dll
#   warnings.warn("loaded more than 1 DLL from .libs:"
# Using cache found in C:\Users\lc100/.cache\torch\hub\ultralytics_yolov5_master
# requirements: Ultralytics requirement "gitpython>=3.1.30" not found, attempting AutoUpdate...
# requirements:  AutoUpdate skipped (offline)
# YOLOv5  2023-6-14 Python-3.11.3 torch-2.0.1+cpu CPU
#
# Fusing layers...
# Model summary: 157 layers, 7018216 parameters, 0 gradients
# Adding AutoShape...

# %%
image=cv2.imread('imgs/20220927_100820.jpg')

height, width, _ = image.shape

# start object detection
# ball detection returns center coordinates from the ball
ball_center, ball_bb = detect_ball(ball_model, image)
if ball_center:  # if ball was detected
    # calculate ball coordinates from 360x360 to current size
    ball_center = [ball_center[0] * (width / 360), ball_center[1] * (height / 360)] 
    ball_bb=[ball_bb[0]* (width / 360),
             ball_bb[1]* (height / 360),
             ball_bb[2]* (width / 360),
             ball_bb[3]* (height / 360)]  

    # # H-4 draw Ball Detection
    cv2.drawMarker(image, (int(ball_center[0]), int(ball_center[1])), (0, 0, 255), cv2.MARKER_CROSS, 10, 2, 8)
    cv2.rectangle(
            image, 
            (int(ball_bb[0]), int(ball_bb[1])), # start_point
            (int(ball_bb[2]), int(ball_bb[3])), # end_point
            (0, 0, 255), # color
            5 #thickness
        )
    cv2.putText(
            image, 
            'Ball', 
            (int(ball_bb[0])-10, int(ball_bb[1])- 10), 
            cv2.FONT_HERSHEY_DUPLEX, 
            2, # text_seize
            (0, 0, 255), # color
            2, # text_thickness 
            cv2.LINE_AA
        )

    cv2.namedWindow('TippKick', cv2.WINDOW_NORMAL)      
    cv2.imshow('TippKick', image)

    cv2.waitKey(0)
    cv2.destroyAllWindows()
# Out:
# Collecting ultralytics
#   Downloading ultralytics-8.0.117-py3-none-any.whl (599 kB)
#      ---------------------------------------- 0.0/599.6 kB ? eta -:--:--
#      ----------------------- -------------- 368.6/599.6 kB 7.6 MB/s eta 0:00:01
#      -------------------------------------- 599.6/599.6 kB 6.3 MB/s eta 0:00:00
# Requirement already satisfied: matplotlib>=3.2.2 in c:\users\lc100\appdata\local\miniconda3\envs\framesubtraction\lib\site-packages (from ultralytics) (3.7.1)
# Requirement already satisfied: opencv-python>=4.6.0 in c:\users\lc100\appdata\local\miniconda3\envs\framesubtraction\lib\site-packages (from ultralytics) (4.7.0.72)
# Requirement already satisfied: Pillow>=7.1.2 in c:\users\lc100\appdata\local\miniconda3\envs\framesubtraction\lib\site-packages (from ultralytics) (9.4.0)
# Requirement already satisfied: PyYAML>=5.3.1 in c:\users\lc100\appdata\local\miniconda3\envs\framesubtraction\lib\site-packages (from ultralytics) (6.0)
# Requirement already satisfied: requests>=2.23.0 in c:\users\lc100\appdata\local\miniconda3\envs\framesubtraction\lib\site-packages (from ultralytics) (2.31.0)
# Requirement already satisfied: scipy>=1.4.1 in c:\users\lc100\appdata\local\miniconda3\envs\framesubtraction\lib\site-packages (from ultralytics) (1.10.1)
# Requirement already satisfied: torch>=1.7.0 in c:\users\lc100\appdata\local\miniconda3\envs\framesubtraction\lib\site-packages (from ultralytics) (2.0.1)
# Requirement already satisfied: torchvision>=0.8.1 in c:\users\lc100\appdata\local\miniconda3\envs\framesubtraction\lib\site-packages (from ultralytics) (0.15.2)
# Requirement already satisfied: tqdm>=4.64.0 in c:\users\lc100\appdata\local\miniconda3\envs\framesubtraction\lib\site-packages (from ultralytics) (4.65.0)
# Requirement already satisfied: pandas>=1.1.4 in c:\users\lc100\appdata\local\miniconda3\envs\framesubtraction\lib\site-packages (from ultralytics) (2.0.2)
# Collecting seaborn>=0.11.0
#   Downloading seaborn-0.12.2-py3-none-any.whl (293 kB)
#      ---------------------------------------- 0.0/293.3 kB ? eta -:--:--
#      -------------------------------------- 293.3/293.3 kB 6.0 MB/s eta 0:00:00
# Requirement already satisfied: psutil in c:\users\lc100\appdata\local\miniconda3\envs\framesubtraction\lib\site-packages (from ultralytics) (5.9.5)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\lc100\appdata\local\miniconda3\envs\framesubtraction\lib\site-packages (from matplotlib>=3.2.2->ultralytics) (1.0.5)
# Requirement already satisfied: cycler>=0.10 in c:\users\lc100\appdata\local\miniconda3\envs\framesubtraction\lib\site-packages (from matplotlib>=3.2.2->ultralytics) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\lc100\appdata\local\miniconda3\envs\framesubtraction\lib\site-packages (from matplotlib>=3.2.2->ultralytics) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\lc100\appdata\local\miniconda3\envs\framesubtraction\lib\site-packages (from matplotlib>=3.2.2->ultralytics) (1.4.4)
# Requirement already satisfied: numpy>=1.20 in c:\users\lc100\appdata\local\miniconda3\envs\framesubtraction\lib\site-packages (from matplotlib>=3.2.2->ultralytics) (1.24.3)
# Requirement already satisfied: packaging>=20.0 in c:\users\lc100\appdata\local\miniconda3\envs\framesubtraction\lib\site-packages (from matplotlib>=3.2.2->ultralytics) (23.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\lc100\appdata\local\miniconda3\envs\framesubtraction\lib\site-packages (from matplotlib>=3.2.2->ultralytics) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\lc100\appdata\local\miniconda3\envs\framesubtraction\lib\site-packages (from matplotlib>=3.2.2->ultralytics) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\lc100\appdata\local\miniconda3\envs\framesubtraction\lib\site-packages (from pandas>=1.1.4->ultralytics) (2023.3)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\lc100\appdata\local\miniconda3\envs\framesubtraction\lib\site-packages (from pandas>=1.1.4->ultralytics) (2023.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\lc100\appdata\local\miniconda3\envs\framesubtraction\lib\site-packages (from requests>=2.23.0->ultralytics) (3.1.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\lc100\appdata\local\miniconda3\envs\framesubtraction\lib\site-packages (from requests>=2.23.0->ultralytics) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\lc100\appdata\local\miniconda3\envs\framesubtraction\lib\site-packages (from requests>=2.23.0->ultralytics) (2.0.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\lc100\appdata\local\miniconda3\envs\framesubtraction\lib\site-packages (from requests>=2.23.0->ultralytics) (2023.5.7)
# Requirement already satisfied: filelock in c:\users\lc100\appdata\local\miniconda3\envs\framesubtraction\lib\site-packages (from torch>=1.7.0->ultralytics) (3.12.2)
# Requirement already satisfied: typing-extensions in c:\users\lc100\appdata\local\miniconda3\envs\framesubtraction\lib\site-packages (from torch>=1.7.0->ultralytics) (4.6.3)
# Requirement already satisfied: sympy in c:\users\lc100\appdata\local\miniconda3\envs\framesubtraction\lib\site-packages (from torch>=1.7.0->ultralytics) (1.12)
# Requirement already satisfied: networkx in c:\users\lc100\appdata\local\miniconda3\envs\framesubtraction\lib\site-packages (from torch>=1.7.0->ultralytics) (3.1)
# Requirement already satisfied: jinja2 in c:\users\lc100\appdata\local\miniconda3\envs\framesubtraction\lib\site-packages (from torch>=1.7.0->ultralytics) (3.1.2)
# Requirement already satisfied: colorama in c:\users\lc100\appdata\local\miniconda3\envs\framesubtraction\lib\site-packages (from tqdm>=4.64.0->ultralytics) (0.4.6)
# Requirement already satisfied: six>=1.5 in c:\users\lc100\appdata\local\miniconda3\envs\framesubtraction\lib\site-packages (from python-dateutil>=2.7->matplotlib>=3.2.2->ultralytics) (1.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\lc100\appdata\local\miniconda3\envs\framesubtraction\lib\site-packages (from jinja2->torch>=1.7.0->ultralytics) (2.1.3)
# Requirement already satisfied: mpmath>=0.19 in c:\users\lc100\appdata\local\miniconda3\envs\framesubtraction\lib\site-packages (from sympy->torch>=1.7.0->ultralytics) (1.3.0)
# Installing collected packages: seaborn, ultralytics
# Successfully installed seaborn-0.12.2 ultralytics-8.0.117
