# %%
import cv2
import numpy as np
import random as rng
from ipynb.fs.full.wavelet import Wavelet
from ipynb.fs.full.white_select import selectGreenHSV
from ipynb.fs.full.subtraction import display
# Out:
# c:\Users\lc100\AppData\Local\miniconda3\envs\frameSubtraction\Lib\site-packages\numpy\_distributor_init.py:30: UserWarning: loaded more than 1 DLL from .libs:
# c:\Users\lc100\AppData\Local\miniconda3\envs\frameSubtraction\Lib\site-packages\numpy\.libs\libopenblas.FB5AE2TYXYH2IJRDKGDGQ3XBKLKTF43H.gfortran-win_amd64.dll
# c:\Users\lc100\AppData\Local\miniconda3\envs\frameSubtraction\Lib\site-packages\numpy\.libs\libopenblas64__v0.3.21-gcc_10_3_0.dll
#   warnings.warn("loaded more than 1 DLL from .libs:"
# very blurry
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# Cell In[1], line 4
#       2 import numpy as np
#       3 import random as rng
# ----> 4 from ipynb.fs.full.wavelet import Wavelet
#       5 from ipynb.fs.full.white_select import selectGreenHSV
#       6 from ipynb.fs.full.subtraction import display
#
# File c:\Users\lc100\Documents\GitHub\ball_detection_app_for_tipp-kick\notebookFile\wavelet.ipynb:138
#       1 {
#       2  "cells": [
#       3   {
#       4    "cell_type": "code",
#       5    "execution_count": 6,
#       6    "id": "7efa6663",
#       7    "metadata": {},
#       8    "outputs": [],
#       9    "source": [
#      10     "import matplotlib.pyplot as plt\n",
#      11     "import cv2\n",
#      12     "import numpy as np\n",
#      13     "import math "
#      14    ]
#      15   },
#      16   {
#      17    "cell_type": "code",
#      18    "execution_count": 7,
#      19    "id": "ba471dd3",
#      20    "metadata": {},
#      21    "outputs": [],
#      22    "source": [
#      23     "def middle(box):\n",
#      24     "    \"\"\"_summary_\n",
#      25     "\n",
#      26     "    Args:\n",
#      27     "        box (array): box\n",
#      28     "\n",
#      29     "    Returns:\n",
#      30     "        int: middle of the box\n",
#      31     "    \"\"\"\n",
#      32     "    return [box[0]+(box[2]//2),box[1]+(box[3]//2)]\n",
#      33     "\n",
#      34     "######################################################################################################\n",
#      35     "\n",
#      36     "def decomp_row(row,size):\n",
#      37     "    \"\"\" decomposition of a row for the wavelet transform\n",
#      38     "\n",
#      39     "    Args:\n",
#      40     "        row (array): row\n",
#      41     "        size (int): biggest power of 2 that contain the frame\n",
#      42     "\n",
#      43     "    Returns:\n",
#      44     "        array: row decomposed\n",
#      45     "    \"\"\"\n",
#      46     "    row=row/math.sqrt(2)\n",
#      47     "    while size>1:\n",
#      48     "        size=size//2\n",
#      49     "        for i in range(size):\n",
#      50     "            A=row[2*i]\n",
#      51     "            B=row[2*i+1]\n",
#      52     "            row[i],row[size+i]=(A+B)/math.sqrt(2),(A-B)/math.sqrt(2)\n",
#      53     "    return row\n",
#      54     "                       \n",
#      55     "######################################################################################################\n",
#      56     "\n",
#      57     "def decomp_2D(img,size):\n",
#      58     "    \"\"\" decomp all the rows of a 2D array\n",
#      59     "    Args:\n",
#      60     "        img (array): 2D frame\n",
#      61     "        size (int): biggest power of 2 that contain the frame\n",
#      62     "\n",
#      63     "    Returns:\n",
#      64     "        array: img decomposed\n",
#      65     "    \"\"\"\n",
#      66     "    for i in range(size):\n",
#      67     "        img[i,:]=decomp_row(img[i,:],i)\n",
#      68     "    return img\n",
#      69     "        \n",
#      70     "######################################################################################################\n",
#      71     "\n",
#      72     "def decomp_RGB(img,size):\n",
#      73     "    \"\"\" decomp of a RGB array\n",
#      74     "\n",
#      75     "    Args:\n",
#      76     "        img (array): RGB array\n",
#      77     "        size (int): biggest power of 2 that contain the frame\n",
#      78     "\n",
#      79     "    Returns:\n",
#      80     "        array: img decomposed\n",
#      81     "    \"\"\"\n",
#      82     "    for i in range(3):\n",
#      83     "        img[:,:,i]=np.transpose(decomp_2D(img[:,:,i],size))\n",
#      84     "        img[:,:,i]=np.transpose(decomp_2D(img[:,:,i],size))\n",
#      85     "    return img\n",
#      86     "\n",
#      87     "######################################################################################################\n",
#      88     "\n",
#      89     "def Wavelet(img):\n",
#      90     "    \"\"\" wavelet Haar transform of a RGB frame\n",
#      91     "\n",
#      92     "    Args:\n",
#      93     "        img (array): RGB frame\n",
#      94     "\n",
#      95     "    Returns:\n",
#      96     "        array: wavelet transform\n",
#      97     "    \"\"\"\n",
#      98     "    img= cv2.cvtColor(img,cv2.COLOR_BGR2HSV)\n",
#      99     "    img=img.astype(np.float)\n",
#     100     "    \n",
#     101     "    n=min(img.shape[0],img.shape[1])\n",
#     102     "    \n",
#     103     "    size = 1\n",
#     104     "    while size < n: size *=2\n",
#     105     "    size//=2\n",
#     106     "    \n",
#     107     "    middle_x=img.shape[0]//2\n",
#     108     "    middle_y=img.shape[1]//2\n",
#     109     "    \n",
#     110     "    resized=img[middle_x-(size//2):middle_x+(size//2),middle_y-(size//2):middle_y+(size//2),:]\n",
#     111     "    #resized = cv2.resize(img,(64,64))\n",
#     112     "    \n",
#     113     "    res=decomp_RGB(resized,size)\n",
#     114     "    \n",
#     115     "    return res\n"
#     116    ]
#     117   },
#     118   {
#     119    "cell_type": "code",
#     120    "execution_count": 8,
#     121    "id": "10ac7a4a",
#     122    "metadata": {},
#     123    "outputs": [
#     124     {
#     125      "name": "stderr",
#     126      "output_type": "stream",
#     127      "text": [
#     128       "C:\\Users\\lc100\\AppData\\Local\\Temp\\ipykernel_12688\\3019806044.py:77: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.\n",
#     129       "Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations\n",
#     130       "  img=img.astype(np.float)\n",
#     131       "Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).\n",
#     132       "Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).\n"
#     133      ]
#     134     },
#     135     {
#     136      "name": "stdout",
#     137      "output_type": "stream",
# --> 138      "text": [
#     139       "\n",
#     140       "very blurry\n",
#     141       "(32, 32, 3)\n",
#     142       "(32, 32, 3)\n"
#     143      ]
#     144     },
#     145     {
#     146      "data": {
#     147       "image/png": "[...",
#     148       "text/plain": [
#     149        "<Figure size 1000x700 with 2 Axes>"
#     150       ]
#     151      },
#     152      "metadata": {},
#     153      "output_type": "display_data"
#     154     },
#     155     {
#     156      "name": "stdout",
#     157      "output_type": "stream",
#     158      "text": [
#     159       "29.499999999999996\n",
#     160       "29.499999999999996\n",
#     161       "29.999999999999993\n",
#     162       "28.999999999999996\n",
#     163       "---------------------------------------------------------------------------------------------\n",
#     164       "[[[29.5 61.  70. ]\n",
#     165       "  [30.  61.  70. ]]\n",
#     166       "\n",
#     167       " [[29.5 61.5 69.5]\n",
#     168       "  [29.  64.  70. ]]] \n",
#     169       "------\n",
#     170       " [[[  0.    0.  127.5]\n",
#     171       "  [  0.    0.  127. ]]\n",
#     172       "\n",
#     173       " [[ 15.    6.  127.5]\n",
#     174       "  [ 15.    6.  127.5]]]\n",
#     175       "\n",
#     176       "------\n",
#     177       " 107.83333333333333\n",
#     178       "---------------------------------------------------------------------------------------------\n"
#     179      ]
#     180     }
#     181    ],
#     182    "source": [
#     183     "def compare(file1,file2):\n",
#     184     "    fig = plt.figure(figsize=(10, 7))\n",
#     185     "\n",
#     186     "    template_test = cv2.imread('template/templateRGB_Black.png')\n",
#     187     "    template_test = cv2.imread(file1)\n",
#     188     "    waveletT=Wavelet(template_test)\n",
#     189     "    print(waveletT.shape)\n",
#     190     "    fig.add_subplot(1,2,1)\n",
#     191     "    plt.imshow(waveletT)\n",
#     192     "\n",
#     193     "\n",
#     194     "    template_test = cv2.imread('template/templateGoal.png')\n",
#     195     "    template_test = cv2.imread(file2)\n",
#     196     "    wavelet=Wavelet(template_test)\n",
#     197     "    print(wavelet.shape)\n",
#     198     "    fig.add_subplot(1,2,2)\n",
#     199     "    plt.imshow(wavelet)\n",
#     200     "\n",
#     201     "    plt.show()\n",
#     202     "    \n",
#     203     "    print(waveletT[0,0,0])\n",
#     204     "    print(waveletT[1,0,0])\n",
#     205     "    print(waveletT[0,1,0])\n",
#     206     "    print(waveletT[1,1,0])\n",
#     207     "    \n",
#     208     "    print(\"---------------------------------------------------------------------------------------------\")\n",
#     209     "\n",
#     210     "    print(waveletT[:2,:2,:],\"\\n------\\n\",wavelet[:2,:2,:])\n",
#     211     "    print(\"\\n------\\n\",np.sum(cv2.absdiff(waveletT[:2,:2,:2],wavelet[:2,:2,:2]))/3)\n",
#     212     "    print(\"---------------------------------------------------------------------------------------------\")\n",
#     213     "\n",
#     214     "print(\"\\nvery blurry\")\n",
#     215     "compare('template/templateRGB_both.png','template/object2.jpg')"
#     216    ]
#     217   },
#     218   {
#     219    "cell_type": "code",
#     220    "execution_count": 9,
#     221    "id": "fe2597f6",
#     222    "metadata": {},
#     223    "outputs": [
#     224     {
#     225      "data": {
#     226       "text/plain": [
#     227        "'\\nimport numpy as np\\nimport matplotlib.pyplot as plt\\n\\n# Signal\\nT = 1.\\n\\ndef signal(t,f=1): return np.sin(2. *f* np.pi * t / T)\\n\\n# Echantillonnage\\nD = 5. # Duree d\\'observation\\nfe = 10. # Frequence d\\'echantillonnage\\nN = int(D * fe) + 1 # Nombre de points enregistres\\n\\ntp = np.linspace(0., D, 1000) # Grille plus fine pour tracer l\\'allure du signal parfait\\ntp2 = np.linspace(D, D*2, 1000) # Grille plus fine pour tracer l\\'allure du signal parfait\\n\\ny=np.concatenate((signal(tp),signal(tp2,f=2)))\\nt=np.concatenate((tp,tp2))\\n\\n# Trace du signal\\n\\nfig = plt.figure(figsize=(12, 3))\\n\\ny=np.concatenate((signal(tp),signal(tp2,f=2)))\\nt=np.concatenate((tp,tp2))\\n\\n\\nfig.add_subplot(1,2,1)\\nplt.plot(t, y, \\'b\\')\\nplt.grid()\\nplt.xlabel(\"Temps $t$\")\\nplt.ylabel(\"Amplitude $x(t)$\")\\n\\n\\ny=np.concatenate((signal(tp,f=2),signal(tp2,f=1)))\\nfig.add_subplot(1,2,2)\\nplt.plot(t, y, \\'b\\')\\nplt.grid()\\nplt.xlabel(\"Temps $t$\")\\nplt.ylabel(\"Amplitude $x(t)$\")\\n\\nplt.show()\\n'"
#     228       ]
#     229      },
#     230      "execution_count": 9,
#     231      "metadata": {},
#     232      "output_type": "execute_result"
#     233     }
#     234    ],
#     235    "source": [
#     236     "\"\"\"\n",
#     237     "import numpy as np\n",
#     238     "import matplotlib.pyplot as plt\n",
#     239     "\n",
#     240     "# Signal\n",
#     241     "T = 1.\n",
#     242     "\n",
#     243     "def signal(t,f=1): return np.sin(2. *f* np.pi * t / T)\n",
#     244     "\n",
#     245     "# Echantillonnage\n",
#     246     "D = 5. # Duree d'observation\n",
#     247     "fe = 10. # Frequence d'echantillonnage\n",
#     248     "N = int(D * fe) + 1 # Nombre de points enregistres\n",
#     249     "\n",
#     250     "tp = np.linspace(0., D, 1000) # Grille plus fine pour tracer l'allure du signal parfait\n",
#     251     "tp2 = np.linspace(D, D*2, 1000) # Grille plus fine pour tracer l'allure du signal parfait\n",
#     252     "\n",
#     253     "y=np.concatenate((signal(tp),signal(tp2,f=2)))\n",
#     254     "t=np.concatenate((tp,tp2))\n",
#     255     "\n",
#     256     "# Trace du signal\n",
#     257     "\n",
#     258     "fig = plt.figure(figsize=(12, 3))\n",
#     259     "\n",
#     260     "y=np.concatenate((signal(tp),signal(tp2,f=2)))\n",
#     261     "t=np.concatenate((tp,tp2))\n",
#     262     "\n",
#     263     "\n",
#     264     "fig.add_subplot(1,2,1)\n",
#     265     "plt.plot(t, y, 'b')\n",
#     266     "plt.grid()\n",
#     267     "plt.xlabel(\"Temps $t$\")\n",
#     268     "plt.ylabel(\"Amplitude $x(t)$\")\n",
#     269     "\n",
#     270     "\n",
#     271     "y=np.concatenate((signal(tp,f=2),signal(tp2,f=1)))\n",
#     272     "fig.add_subplot(1,2,2)\n",
#     273     "plt.plot(t, y, 'b')\n",
#     274     "plt.grid()\n",
#     275     "plt.xlabel(\"Temps $t$\")\n",
#     276     "plt.ylabel(\"Amplitude $x(t)$\")\n",
#     277     "\n",
#     278     "plt.show()\n",
#     279     "\"\"\"\n"
#     280    ]
#     281   },
#     282   {
#     283    "cell_type": "code",
#     284    "execution_count": 10,
#     285    "id": "f836a8be",
#     286    "metadata": {},
#     287    "outputs": [
#     288     {
#     289      "data": {
#     290       "text/plain": [
#     291        "'\\nimport numpy as np\\nimport matplotlib.pyplot as plt\\n\\n# Signal\\nT = 1.\\n\\ndef signalMorlet(t,f=1): return np.sin(2. *f* np.pi * t / T)*math.e**(-(t**2)/2)\\n\\n# Echantillonnage\\nD = 10. # Duree d\\'observation\\n\\ntp = np.linspace(-D/2, D/2, 1000) # Grille plus fine pour tracer l\\'allure du signal parfait\\n\\ny=signalMorlet(t,f=1)\\n\\n# Trace du signal\\n\\nfig = plt.figure(figsize=(12, 3))\\n\\n\\nfig.add_subplot(1,2,1)\\nplt.plot(tp, signalMorlet(tp), \\'b\\')\\nplt.grid()\\nplt.xlabel(\"Temps $t$\")\\nplt.ylabel(\"Amplitude $x(t)$\")\\n\\n\\nfig.add_subplot(1,2,2)\\n\\nt=[ 0. , 0.5]\\ny=[ 1. , 1.]\\nplt.plot(t, y, \\'b\\')\\nt=[ 0.5 , 1.]\\ny=[ -1. , -1.]\\nplt.plot(t, y, \\'b\\')\\nt=[ 1. , 2.]\\ny=[ 0. , 0.]\\nplt.plot(t, y, \\'b\\')\\nt=[ -1. , 0.]\\ny=[ 0., 0.]\\nplt.plot(t, y, \\'b\\')\\nt=[ 0. , 0.]\\ny=[ 0. , 1.]\\nplt.plot(t, y, \\'b\\')\\nt=[ 1. , 1.]\\ny=[ 0. , -1.]\\nplt.plot(t, y, \\'b\\')\\nt=[ 0.5 , 0.5]\\ny=[ 1. , -1.]\\nplt.plot(t, y, \\'b\\')\\nplt.grid()\\nplt.xlabel(\"Temps $t$\")\\nplt.ylabel(\"Amplitude $x(t)$\")\\n\\nplt.show()\\n'"
#     292       ]
#     293      },
#     294      "execution_count": 10,
#     295      "metadata": {},
#     296      "output_type": "execute_result"
#     297     }
#     298    ],
#     299    "source": [
#     300     "\"\"\"\n",
#     301     "import numpy as np\n",
#     302     "import matplotlib.pyplot as plt\n",
#     303     "\n",
#     304     "# Signal\n",
#     305     "T = 1.\n",
#     306     "\n",
#     307     "def signalMorlet(t,f=1): return np.sin(2. *f* np.pi * t / T)*math.e**(-(t**2)/2)\n",
#     308     "\n",
#     309     "# Echantillonnage\n",
#     310     "D = 10. # Duree d'observation\n",
#     311     "\n",
#     312     "tp = np.linspace(-D/2, D/2, 1000) # Grille plus fine pour tracer l'allure du signal parfait\n",
#     313     "\n",
#     314     "y=signalMorlet(t,f=1)\n",
#     315     "\n",
#     316     "# Trace du signal\n",
#     317     "\n",
#     318     "fig = plt.figure(figsize=(12, 3))\n",
#     319     "\n",
#     320     "\n",
#     321     "fig.add_subplot(1,2,1)\n",
#     322     "plt.plot(tp, signalMorlet(tp), 'b')\n",
#     323     "plt.grid()\n",
#     324     "plt.xlabel(\"Temps $t$\")\n",
#     325     "plt.ylabel(\"Amplitude $x(t)$\")\n",
#     326     "\n",
#     327     "\n",
#     328     "fig.add_subplot(1,2,2)\n",
#     329     "\n",
#     330     "t=[ 0. , 0.5]\n",
#     331     "y=[ 1. , 1.]\n",
#     332     "plt.plot(t, y, 'b')\n",
#     333     "t=[ 0.5 , 1.]\n",
#     334     "y=[ -1. , -1.]\n",
#     335     "plt.plot(t, y, 'b')\n",
#     336     "t=[ 1. , 2.]\n",
#     337     "y=[ 0. , 0.]\n",
#     338     "plt.plot(t, y, 'b')\n",
#     339     "t=[ -1. , 0.]\n",
#     340     "y=[ 0., 0.]\n",
#     341     "plt.plot(t, y, 'b')\n",
#     342     "t=[ 0. , 0.]\n",
#     343     "y=[ 0. , 1.]\n",
#     344     "plt.plot(t, y, 'b')\n",
#     345     "t=[ 1. , 1.]\n",
#     346     "y=[ 0. , -1.]\n",
#     347     "plt.plot(t, y, 'b')\n",
#     348     "t=[ 0.5 , 0.5]\n",
#     349     "y=[ 1. , -1.]\n",
#     350     "plt.plot(t, y, 'b')\n",
#     351     "plt.grid()\n",
#     352     "plt.xlabel(\"Temps $t$\")\n",
#     353     "plt.ylabel(\"Amplitude $x(t)$\")\n",
#     354     "\n",
#     355     "plt.show()\n",
#     356     "\"\"\""
#     357    ]
#     358   }
#     359  ],
#     360  "metadata": {
#     361   "kernelspec": {
#     362    "display_name": "Python 3 (ipykernel)",
#     363    "language": "python",
#     364    "name": "python3"
#     365   },
#     366   "language_info": {
#     367    "codemirror_mode": {
#     368     "name": "ipython",
#     369     "version": 3
#     370    },
#     371    "file_extension": ".py",
#     372    "mimetype": "text/x-python",
#     373    "name": "python",
#     374    "nbconvert_exporter": "python",
#     375    "pygments_lexer": "ipython3",
#     376    "version": "3.11.3"
#     377   }
#     378  },
#     379  "nbformat": 4,
#     380  "nbformat_minor": 5
#     381 }
#
# File c:\Users\lc100\Documents\GitHub\ball_detection_app_for_tipp-kick\notebookFile\wavelet.ipynb:111, in compare(file1, file2)
#       1 {
#       2  "cells": [
#       3   {
#       4    "cell_type": "code",
#       5    "execution_count": 6,
#       6    "id": "7efa6663",
#       7    "metadata": {},
#       8    "outputs": [],
#       9    "source": [
#      10     "import matplotlib.pyplot as plt\n",
#      11     "import cv2\n",
#      12     "import numpy as np\n",
#      13     "import math "
#      14    ]
#      15   },
#      16   {
#      17    "cell_type": "code",
#      18    "execution_count": 7,
#      19    "id": "ba471dd3",
#      20    "metadata": {},
#      21    "outputs": [],
#      22    "source": [
#      23     "def middle(box):\n",
#      24     "    \"\"\"_summary_\n",
#      25     "\n",
#      26     "    Args:\n",
#      27     "        box (array): box\n",
#      28     "\n",
#      29     "    Returns:\n",
#      30     "        int: middle of the box\n",
#      31     "    \"\"\"\n",
#      32     "    return [box[0]+(box[2]//2),box[1]+(box[3]//2)]\n",
#      33     "\n",
#      34     "######################################################################################################\n",
#      35     "\n",
#      36     "def decomp_row(row,size):\n",
#      37     "    \"\"\" decomposition of a row for the wavelet transform\n",
#      38     "\n",
#      39     "    Args:\n",
#      40     "        row (array): row\n",
#      41     "        size (int): biggest power of 2 that contain the frame\n",
#      42     "\n",
#      43     "    Returns:\n",
#      44     "        array: row decomposed\n",
#      45     "    \"\"\"\n",
#      46     "    row=row/math.sqrt(2)\n",
#      47     "    while size>1:\n",
#      48     "        size=size//2\n",
#      49     "        for i in range(size):\n",
#      50     "            A=row[2*i]\n",
#      51     "            B=row[2*i+1]\n",
#      52     "            row[i],row[size+i]=(A+B)/math.sqrt(2),(A-B)/math.sqrt(2)\n",
#      53     "    return row\n",
#      54     "                       \n",
#      55     "######################################################################################################\n",
#      56     "\n",
#      57     "def decomp_2D(img,size):\n",
#      58     "    \"\"\" decomp all the rows of a 2D array\n",
#      59     "    Args:\n",
#      60     "        img (array): 2D frame\n",
#      61     "        size (int): biggest power of 2 that contain the frame\n",
#      62     "\n",
#      63     "    Returns:\n",
#      64     "        array: img decomposed\n",
#      65     "    \"\"\"\n",
#      66     "    for i in range(size):\n",
#      67     "        img[i,:]=decomp_row(img[i,:],i)\n",
#      68     "    return img\n",
#      69     "        \n",
#      70     "######################################################################################################\n",
#      71     "\n",
#      72     "def decomp_RGB(img,size):\n",
#      73     "    \"\"\" decomp of a RGB array\n",
#      74     "\n",
#      75     "    Args:\n",
#      76     "        img (array): RGB array\n",
#      77     "        size (int): biggest power of 2 that contain the frame\n",
#      78     "\n",
#      79     "    Returns:\n",
#      80     "        array: img decomposed\n",
#      81     "    \"\"\"\n",
#      82     "    for i in range(3):\n",
#      83     "        img[:,:,i]=np.transpose(decomp_2D(img[:,:,i],size))\n",
#      84     "        img[:,:,i]=np.transpose(decomp_2D(img[:,:,i],size))\n",
#      85     "    return img\n",
#      86     "\n",
#      87     "######################################################################################################\n",
#      88     "\n",
#      89     "def Wavelet(img):\n",
#      90     "    \"\"\" wavelet Haar transform of a RGB frame\n",
#      91     "\n",
#      92     "    Args:\n",
#      93     "        img (array): RGB frame\n",
#      94     "\n",
#      95     "    Returns:\n",
#      96     "        array: wavelet transform\n",
#      97     "    \"\"\"\n",
#      98     "    img= cv2.cvtColor(img,cv2.COLOR_BGR2HSV)\n",
#      99     "    img=img.astype(np.float)\n",
#     100     "    \n",
#     101     "    n=min(img.shape[0],img.shape[1])\n",
#     102     "    \n",
#     103     "    size = 1\n",
#     104     "    while size < n: size *=2\n",
#     105     "    size//=2\n",
#     106     "    \n",
#     107     "    middle_x=img.shape[0]//2\n",
#     108     "    middle_y=img.shape[1]//2\n",
#     109     "    \n",
#     110     "    resized=img[middle_x-(size//2):middle_x+(size//2),middle_y-(size//2):middle_y+(size//2),:]\n",
# --> 111     "    #resized = cv2.resize(img,(64,64))\n",
#     112     "    \n",
#     113     "    res=decomp_RGB(resized,size)\n",
#     114     "    \n",
#     115     "    return res\n"
#     116    ]
#     117   },
#     118   {
#     119    "cell_type": "code",
#     120    "execution_count": 8,
#     121    "id": "10ac7a4a",
#     122    "metadata": {},
#     123    "outputs": [
#     124     {
#     125      "name": "stderr",
#     126      "output_type": "stream",
#     127      "text": [
#     128       "C:\\Users\\lc100\\AppData\\Local\\Temp\\ipykernel_12688\\3019806044.py:77: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.\n",
#     129       "Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations\n",
#     130       "  img=img.astype(np.float)\n",
#     131       "Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).\n",
#     132       "Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).\n"
#     133      ]
#     134     },
#     135     {
#     136      "name": "stdout",
#     137      "output_type": "stream",
#     138      "text": [
#     139       "\n",
#     140       "very blurry\n",
#     141       "(32, 32, 3)\n",
#     142       "(32, 32, 3)\n"
#     143      ]
#     144     },
#     145     {
#     146      "data": {
#     147       "image/png": "[...",
#     148       "text/plain": [
#     149        "<Figure size 1000x700 with 2 Axes>"
#     150       ]
#     151      },
#     152      "metadata": {},
#     153      "output_type": "display_data"
#     154     },
#     155     {
#     156      "name": "stdout",
#     157      "output_type": "stream",
#     158      "text": [
#     159       "29.499999999999996\n",
#     160       "29.499999999999996\n",
#     161       "29.999999999999993\n",
#     162       "28.999999999999996\n",
#     163       "---------------------------------------------------------------------------------------------\n",
#     164       "[[[29.5 61.  70. ]\n",
#     165       "  [30.  61.  70. ]]\n",
#     166       "\n",
#     167       " [[29.5 61.5 69.5]\n",
#     168       "  [29.  64.  70. ]]] \n",
#     169       "------\n",
#     170       " [[[  0.    0.  127.5]\n",
#     171       "  [  0.    0.  127. ]]\n",
#     172       "\n",
#     173       " [[ 15.    6.  127.5]\n",
#     174       "  [ 15.    6.  127.5]]]\n",
#     175       "\n",
#     176       "------\n",
#     177       " 107.83333333333333\n",
#     178       "---------------------------------------------------------------------------------------------\n"
#     179      ]
#     180     }
#     181    ],
#     182    "source": [
#     183     "def compare(file1,file2):\n",
#     184     "    fig = plt.figure(figsize=(10, 7))\n",
#     185     "\n",
#     186     "    template_test = cv2.imread('template/templateRGB_Black.png')\n",
#     187     "    template_test = cv2.imread(file1)\n",
#     188     "    waveletT=Wavelet(template_test)\n",
#     189     "    print(waveletT.shape)\n",
#     190     "    fig.add_subplot(1,2,1)\n",
#     191     "    plt.imshow(waveletT)\n",
#     192     "\n",
#     193     "\n",
#     194     "    template_test = cv2.imread('template/templateGoal.png')\n",
#     195     "    template_test = cv2.imread(file2)\n",
#     196     "    wavelet=Wavelet(template_test)\n",
#     197     "    print(wavelet.shape)\n",
#     198     "    fig.add_subplot(1,2,2)\n",
#     199     "    plt.imshow(wavelet)\n",
#     200     "\n",
#     201     "    plt.show()\n",
#     202     "    \n",
#     203     "    print(waveletT[0,0,0])\n",
#     204     "    print(waveletT[1,0,0])\n",
#     205     "    print(waveletT[0,1,0])\n",
#     206     "    print(waveletT[1,1,0])\n",
#     207     "    \n",
#     208     "    print(\"---------------------------------------------------------------------------------------------\")\n",
#     209     "\n",
#     210     "    print(waveletT[:2,:2,:],\"\\n------\\n\",wavelet[:2,:2,:])\n",
#     211     "    print(\"\\n------\\n\",np.sum(cv2.absdiff(waveletT[:2,:2,:2],wavelet[:2,:2,:2]))/3)\n",
#     212     "    print(\"---------------------------------------------------------------------------------------------\")\n",
#     213     "\n",
#     214     "print(\"\\nvery blurry\")\n",
#     215     "compare('template/templateRGB_both.png','template/object2.jpg')"
#     216    ]
#     217   },
#     218   {
#     219    "cell_type": "code",
#     220    "execution_count": 9,
#     221    "id": "fe2597f6",
#     222    "metadata": {},
#     223    "outputs": [
#     224     {
#     225      "data": {
#     226       "text/plain": [
#     227        "'\\nimport numpy as np\\nimport matplotlib.pyplot as plt\\n\\n# Signal\\nT = 1.\\n\\ndef signal(t,f=1): return np.sin(2. *f* np.pi * t / T)\\n\\n# Echantillonnage\\nD = 5. # Duree d\\'observation\\nfe = 10. # Frequence d\\'echantillonnage\\nN = int(D * fe) + 1 # Nombre de points enregistres\\n\\ntp = np.linspace(0., D, 1000) # Grille plus fine pour tracer l\\'allure du signal parfait\\ntp2 = np.linspace(D, D*2, 1000) # Grille plus fine pour tracer l\\'allure du signal parfait\\n\\ny=np.concatenate((signal(tp),signal(tp2,f=2)))\\nt=np.concatenate((tp,tp2))\\n\\n# Trace du signal\\n\\nfig = plt.figure(figsize=(12, 3))\\n\\ny=np.concatenate((signal(tp),signal(tp2,f=2)))\\nt=np.concatenate((tp,tp2))\\n\\n\\nfig.add_subplot(1,2,1)\\nplt.plot(t, y, \\'b\\')\\nplt.grid()\\nplt.xlabel(\"Temps $t$\")\\nplt.ylabel(\"Amplitude $x(t)$\")\\n\\n\\ny=np.concatenate((signal(tp,f=2),signal(tp2,f=1)))\\nfig.add_subplot(1,2,2)\\nplt.plot(t, y, \\'b\\')\\nplt.grid()\\nplt.xlabel(\"Temps $t$\")\\nplt.ylabel(\"Amplitude $x(t)$\")\\n\\nplt.show()\\n'"
#     228       ]
#     229      },
#     230      "execution_count": 9,
#     231      "metadata": {},
#     232      "output_type": "execute_result"
#     233     }
#     234    ],
#     235    "source": [
#     236     "\"\"\"\n",
#     237     "import numpy as np\n",
#     238     "import matplotlib.pyplot as plt\n",
#     239     "\n",
#     240     "# Signal\n",
#     241     "T = 1.\n",
#     242     "\n",
#     243     "def signal(t,f=1): return np.sin(2. *f* np.pi * t / T)\n",
#     244     "\n",
#     245     "# Echantillonnage\n",
#     246     "D = 5. # Duree d'observation\n",
#     247     "fe = 10. # Frequence d'echantillonnage\n",
#     248     "N = int(D * fe) + 1 # Nombre de points enregistres\n",
#     249     "\n",
#     250     "tp = np.linspace(0., D, 1000) # Grille plus fine pour tracer l'allure du signal parfait\n",
#     251     "tp2 = np.linspace(D, D*2, 1000) # Grille plus fine pour tracer l'allure du signal parfait\n",
#     252     "\n",
#     253     "y=np.concatenate((signal(tp),signal(tp2,f=2)))\n",
#     254     "t=np.concatenate((tp,tp2))\n",
#     255     "\n",
#     256     "# Trace du signal\n",
#     257     "\n",
#     258     "fig = plt.figure(figsize=(12, 3))\n",
#     259     "\n",
#     260     "y=np.concatenate((signal(tp),signal(tp2,f=2)))\n",
#     261     "t=np.concatenate((tp,tp2))\n",
#     262     "\n",
#     263     "\n",
#     264     "fig.add_subplot(1,2,1)\n",
#     265     "plt.plot(t, y, 'b')\n",
#     266     "plt.grid()\n",
#     267     "plt.xlabel(\"Temps $t$\")\n",
#     268     "plt.ylabel(\"Amplitude $x(t)$\")\n",
#     269     "\n",
#     270     "\n",
#     271     "y=np.concatenate((signal(tp,f=2),signal(tp2,f=1)))\n",
#     272     "fig.add_subplot(1,2,2)\n",
#     273     "plt.plot(t, y, 'b')\n",
#     274     "plt.grid()\n",
#     275     "plt.xlabel(\"Temps $t$\")\n",
#     276     "plt.ylabel(\"Amplitude $x(t)$\")\n",
#     277     "\n",
#     278     "plt.show()\n",
#     279     "\"\"\"\n"
#     280    ]
#     281   },
#     282   {
#     283    "cell_type": "code",
#     284    "execution_count": 10,
#     285    "id": "f836a8be",
#     286    "metadata": {},
#     287    "outputs": [
#     288     {
#     289      "data": {
#     290       "text/plain": [
#     291        "'\\nimport numpy as np\\nimport matplotlib.pyplot as plt\\n\\n# Signal\\nT = 1.\\n\\ndef signalMorlet(t,f=1): return np.sin(2. *f* np.pi * t / T)*math.e**(-(t**2)/2)\\n\\n# Echantillonnage\\nD = 10. # Duree d\\'observation\\n\\ntp = np.linspace(-D/2, D/2, 1000) # Grille plus fine pour tracer l\\'allure du signal parfait\\n\\ny=signalMorlet(t,f=1)\\n\\n# Trace du signal\\n\\nfig = plt.figure(figsize=(12, 3))\\n\\n\\nfig.add_subplot(1,2,1)\\nplt.plot(tp, signalMorlet(tp), \\'b\\')\\nplt.grid()\\nplt.xlabel(\"Temps $t$\")\\nplt.ylabel(\"Amplitude $x(t)$\")\\n\\n\\nfig.add_subplot(1,2,2)\\n\\nt=[ 0. , 0.5]\\ny=[ 1. , 1.]\\nplt.plot(t, y, \\'b\\')\\nt=[ 0.5 , 1.]\\ny=[ -1. , -1.]\\nplt.plot(t, y, \\'b\\')\\nt=[ 1. , 2.]\\ny=[ 0. , 0.]\\nplt.plot(t, y, \\'b\\')\\nt=[ -1. , 0.]\\ny=[ 0., 0.]\\nplt.plot(t, y, \\'b\\')\\nt=[ 0. , 0.]\\ny=[ 0. , 1.]\\nplt.plot(t, y, \\'b\\')\\nt=[ 1. , 1.]\\ny=[ 0. , -1.]\\nplt.plot(t, y, \\'b\\')\\nt=[ 0.5 , 0.5]\\ny=[ 1. , -1.]\\nplt.plot(t, y, \\'b\\')\\nplt.grid()\\nplt.xlabel(\"Temps $t$\")\\nplt.ylabel(\"Amplitude $x(t)$\")\\n\\nplt.show()\\n'"
#     292       ]
#     293      },
#     294      "execution_count": 10,
#     295      "metadata": {},
#     296      "output_type": "execute_result"
#     297     }
#     298    ],
#     299    "source": [
#     300     "\"\"\"\n",
#     301     "import numpy as np\n",
#     302     "import matplotlib.pyplot as plt\n",
#     303     "\n",
#     304     "# Signal\n",
#     305     "T = 1.\n",
#     306     "\n",
#     307     "def signalMorlet(t,f=1): return np.sin(2. *f* np.pi * t / T)*math.e**(-(t**2)/2)\n",
#     308     "\n",
#     309     "# Echantillonnage\n",
#     310     "D = 10. # Duree d'observation\n",
#     311     "\n",
#     312     "tp = np.linspace(-D/2, D/2, 1000) # Grille plus fine pour tracer l'allure du signal parfait\n",
#     313     "\n",
#     314     "y=signalMorlet(t,f=1)\n",
#     315     "\n",
#     316     "# Trace du signal\n",
#     317     "\n",
#     318     "fig = plt.figure(figsize=(12, 3))\n",
#     319     "\n",
#     320     "\n",
#     321     "fig.add_subplot(1,2,1)\n",
#     322     "plt.plot(tp, signalMorlet(tp), 'b')\n",
#     323     "plt.grid()\n",
#     324     "plt.xlabel(\"Temps $t$\")\n",
#     325     "plt.ylabel(\"Amplitude $x(t)$\")\n",
#     326     "\n",
#     327     "\n",
#     328     "fig.add_subplot(1,2,2)\n",
#     329     "\n",
#     330     "t=[ 0. , 0.5]\n",
#     331     "y=[ 1. , 1.]\n",
#     332     "plt.plot(t, y, 'b')\n",
#     333     "t=[ 0.5 , 1.]\n",
#     334     "y=[ -1. , -1.]\n",
#     335     "plt.plot(t, y, 'b')\n",
#     336     "t=[ 1. , 2.]\n",
#     337     "y=[ 0. , 0.]\n",
#     338     "plt.plot(t, y, 'b')\n",
#     339     "t=[ -1. , 0.]\n",
#     340     "y=[ 0., 0.]\n",
#     341     "plt.plot(t, y, 'b')\n",
#     342     "t=[ 0. , 0.]\n",
#     343     "y=[ 0. , 1.]\n",
#     344     "plt.plot(t, y, 'b')\n",
#     345     "t=[ 1. , 1.]\n",
#     346     "y=[ 0. , -1.]\n",
#     347     "plt.plot(t, y, 'b')\n",
#     348     "t=[ 0.5 , 0.5]\n",
#     349     "y=[ 1. , -1.]\n",
#     350     "plt.plot(t, y, 'b')\n",
#     351     "plt.grid()\n",
#     352     "plt.xlabel(\"Temps $t$\")\n",
#     353     "plt.ylabel(\"Amplitude $x(t)$\")\n",
#     354     "\n",
#     355     "plt.show()\n",
#     356     "\"\"\""
#     357    ]
#     358   }
#     359  ],
#     360  "metadata": {
#     361   "kernelspec": {
#     362    "display_name": "Python 3 (ipykernel)",
#     363    "language": "python",
#     364    "name": "python3"
#     365   },
#     366   "language_info": {
#     367    "codemirror_mode": {
#     368     "name": "ipython",
#     369     "version": 3
#     370    },
#     371    "file_extension": ".py",
#     372    "mimetype": "text/x-python",
#     373    "name": "python",
#     374    "nbconvert_exporter": "python",
#     375    "pygments_lexer": "ipython3",
#     376    "version": "3.11.3"
#     377   }
#     378  },
#     379  "nbformat": 4,
#     380  "nbformat_minor": 5
#     381 }
#
# File c:\Users\lc100\Documents\GitHub\ball_detection_app_for_tipp-kick\notebookFile\wavelet.ipynb:86, in Wavelet(img)
#       1 {
#       2  "cells": [
#       3   {
#       4    "cell_type": "code",
#       5    "execution_count": 6,
#       6    "id": "7efa6663",
#       7    "metadata": {},
#       8    "outputs": [],
#       9    "source": [
#      10     "import matplotlib.pyplot as plt\n",
#      11     "import cv2\n",
#      12     "import numpy as np\n",
#      13     "import math "
#      14    ]
#      15   },
#      16   {
#      17    "cell_type": "code",
#      18    "execution_count": 7,
#      19    "id": "ba471dd3",
#      20    "metadata": {},
#      21    "outputs": [],
#      22    "source": [
#      23     "def middle(box):\n",
#      24     "    \"\"\"_summary_\n",
#      25     "\n",
#      26     "    Args:\n",
#      27     "        box (array): box\n",
#      28     "\n",
#      29     "    Returns:\n",
#      30     "        int: middle of the box\n",
#      31     "    \"\"\"\n",
#      32     "    return [box[0]+(box[2]//2),box[1]+(box[3]//2)]\n",
#      33     "\n",
#      34     "######################################################################################################\n",
#      35     "\n",
#      36     "def decomp_row(row,size):\n",
#      37     "    \"\"\" decomposition of a row for the wavelet transform\n",
#      38     "\n",
#      39     "    Args:\n",
#      40     "        row (array): row\n",
#      41     "        size (int): biggest power of 2 that contain the frame\n",
#      42     "\n",
#      43     "    Returns:\n",
#      44     "        array: row decomposed\n",
#      45     "    \"\"\"\n",
#      46     "    row=row/math.sqrt(2)\n",
#      47     "    while size>1:\n",
#      48     "        size=size//2\n",
#      49     "        for i in range(size):\n",
#      50     "            A=row[2*i]\n",
#      51     "            B=row[2*i+1]\n",
#      52     "            row[i],row[size+i]=(A+B)/math.sqrt(2),(A-B)/math.sqrt(2)\n",
#      53     "    return row\n",
#      54     "                       \n",
#      55     "######################################################################################################\n",
#      56     "\n",
#      57     "def decomp_2D(img,size):\n",
#      58     "    \"\"\" decomp all the rows of a 2D array\n",
#      59     "    Args:\n",
#      60     "        img (array): 2D frame\n",
#      61     "        size (int): biggest power of 2 that contain the frame\n",
#      62     "\n",
#      63     "    Returns:\n",
#      64     "        array: img decomposed\n",
#      65     "    \"\"\"\n",
#      66     "    for i in range(size):\n",
#      67     "        img[i,:]=decomp_row(img[i,:],i)\n",
#      68     "    return img\n",
#      69     "        \n",
#      70     "######################################################################################################\n",
#      71     "\n",
#      72     "def decomp_RGB(img,size):\n",
#      73     "    \"\"\" decomp of a RGB array\n",
#      74     "\n",
#      75     "    Args:\n",
#      76     "        img (array): RGB array\n",
#      77     "        size (int): biggest power of 2 that contain the frame\n",
#      78     "\n",
#      79     "    Returns:\n",
#      80     "        array: img decomposed\n",
#      81     "    \"\"\"\n",
#      82     "    for i in range(3):\n",
#      83     "        img[:,:,i]=np.transpose(decomp_2D(img[:,:,i],size))\n",
#      84     "        img[:,:,i]=np.transpose(decomp_2D(img[:,:,i],size))\n",
#      85     "    return img\n",
# ---> 86     "\n",
#      87     "######################################################################################################\n",
#      88     "\n",
#      89     "def Wavelet(img):\n",
#      90     "    \"\"\" wavelet Haar transform of a RGB frame\n",
#      91     "\n",
#      92     "    Args:\n",
#      93     "        img (array): RGB frame\n",
#      94     "\n",
#      95     "    Returns:\n",
#      96     "        array: wavelet transform\n",
#      97     "    \"\"\"\n",
#      98     "    img= cv2.cvtColor(img,cv2.COLOR_BGR2HSV)\n",
#      99     "    img=img.astype(np.float)\n",
#     100     "    \n",
#     101     "    n=min(img.shape[0],img.shape[1])\n",
#     102     "    \n",
#     103     "    size = 1\n",
#     104     "    while size < n: size *=2\n",
#     105     "    size//=2\n",
#     106     "    \n",
#     107     "    middle_x=img.shape[0]//2\n",
#     108     "    middle_y=img.shape[1]//2\n",
#     109     "    \n",
#     110     "    resized=img[middle_x-(size//2):middle_x+(size//2),middle_y-(size//2):middle_y+(size//2),:]\n",
#     111     "    #resized = cv2.resize(img,(64,64))\n",
#     112     "    \n",
#     113     "    res=decomp_RGB(resized,size)\n",
#     114     "    \n",
#     115     "    return res\n"
#     116    ]
#     117   },
#     118   {
#     119    "cell_type": "code",
#     120    "execution_count": 8,
#     121    "id": "10ac7a4a",
#     122    "metadata": {},
#     123    "outputs": [
#     124     {
#     125      "name": "stderr",
#     126      "output_type": "stream",
#     127      "text": [
#     128       "C:\\Users\\lc100\\AppData\\Local\\Temp\\ipykernel_12688\\3019806044.py:77: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.\n",
#     129       "Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations\n",
#     130       "  img=img.astype(np.float)\n",
#     131       "Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).\n",
#     132       "Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).\n"
#     133      ]
#     134     },
#     135     {
#     136      "name": "stdout",
#     137      "output_type": "stream",
#     138      "text": [
#     139       "\n",
#     140       "very blurry\n",
#     141       "(32, 32, 3)\n",
#     142       "(32, 32, 3)\n"
#     143      ]
#     144     },
#     145     {
#     146      "data": {
#     147       "image/png": "[...",
#     148       "text/plain": [
#     149        "<Figure size 1000x700 with 2 Axes>"
#     150       ]
#     151      },
#     152      "metadata": {},
#     153      "output_type": "display_data"
#     154     },
#     155     {
#     156      "name": "stdout",
#     157      "output_type": "stream",
#     158      "text": [
#     159       "29.499999999999996\n",
#     160       "29.499999999999996\n",
#     161       "29.999999999999993\n",
#     162       "28.999999999999996\n",
#     163       "---------------------------------------------------------------------------------------------\n",
#     164       "[[[29.5 61.  70. ]\n",
#     165       "  [30.  61.  70. ]]\n",
#     166       "\n",
#     167       " [[29.5 61.5 69.5]\n",
#     168       "  [29.  64.  70. ]]] \n",
#     169       "------\n",
#     170       " [[[  0.    0.  127.5]\n",
#     171       "  [  0.    0.  127. ]]\n",
#     172       "\n",
#     173       " [[ 15.    6.  127.5]\n",
#     174       "  [ 15.    6.  127.5]]]\n",
#     175       "\n",
#     176       "------\n",
#     177       " 107.83333333333333\n",
#     178       "---------------------------------------------------------------------------------------------\n"
#     179      ]
#     180     }
#     181    ],
#     182    "source": [
#     183     "def compare(file1,file2):\n",
#     184     "    fig = plt.figure(figsize=(10, 7))\n",
#     185     "\n",
#     186     "    template_test = cv2.imread('template/templateRGB_Black.png')\n",
#     187     "    template_test = cv2.imread(file1)\n",
#     188     "    waveletT=Wavelet(template_test)\n",
#     189     "    print(waveletT.shape)\n",
#     190     "    fig.add_subplot(1,2,1)\n",
#     191     "    plt.imshow(waveletT)\n",
#     192     "\n",
#     193     "\n",
#     194     "    template_test = cv2.imread('template/templateGoal.png')\n",
#     195     "    template_test = cv2.imread(file2)\n",
#     196     "    wavelet=Wavelet(template_test)\n",
#     197     "    print(wavelet.shape)\n",
#     198     "    fig.add_subplot(1,2,2)\n",
#     199     "    plt.imshow(wavelet)\n",
#     200     "\n",
#     201     "    plt.show()\n",
#     202     "    \n",
#     203     "    print(waveletT[0,0,0])\n",
#     204     "    print(waveletT[1,0,0])\n",
#     205     "    print(waveletT[0,1,0])\n",
#     206     "    print(waveletT[1,1,0])\n",
#     207     "    \n",
#     208     "    print(\"---------------------------------------------------------------------------------------------\")\n",
#     209     "\n",
#     210     "    print(waveletT[:2,:2,:],\"\\n------\\n\",wavelet[:2,:2,:])\n",
#     211     "    print(\"\\n------\\n\",np.sum(cv2.absdiff(waveletT[:2,:2,:2],wavelet[:2,:2,:2]))/3)\n",
#     212     "    print(\"---------------------------------------------------------------------------------------------\")\n",
#     213     "\n",
#     214     "print(\"\\nvery blurry\")\n",
#     215     "compare('template/templateRGB_both.png','template/object2.jpg')"
#     216    ]
#     217   },
#     218   {
#     219    "cell_type": "code",
#     220    "execution_count": 9,
#     221    "id": "fe2597f6",
#     222    "metadata": {},
#     223    "outputs": [
#     224     {
#     225      "data": {
#     226       "text/plain": [
#     227        "'\\nimport numpy as np\\nimport matplotlib.pyplot as plt\\n\\n# Signal\\nT = 1.\\n\\ndef signal(t,f=1): return np.sin(2. *f* np.pi * t / T)\\n\\n# Echantillonnage\\nD = 5. # Duree d\\'observation\\nfe = 10. # Frequence d\\'echantillonnage\\nN = int(D * fe) + 1 # Nombre de points enregistres\\n\\ntp = np.linspace(0., D, 1000) # Grille plus fine pour tracer l\\'allure du signal parfait\\ntp2 = np.linspace(D, D*2, 1000) # Grille plus fine pour tracer l\\'allure du signal parfait\\n\\ny=np.concatenate((signal(tp),signal(tp2,f=2)))\\nt=np.concatenate((tp,tp2))\\n\\n# Trace du signal\\n\\nfig = plt.figure(figsize=(12, 3))\\n\\ny=np.concatenate((signal(tp),signal(tp2,f=2)))\\nt=np.concatenate((tp,tp2))\\n\\n\\nfig.add_subplot(1,2,1)\\nplt.plot(t, y, \\'b\\')\\nplt.grid()\\nplt.xlabel(\"Temps $t$\")\\nplt.ylabel(\"Amplitude $x(t)$\")\\n\\n\\ny=np.concatenate((signal(tp,f=2),signal(tp2,f=1)))\\nfig.add_subplot(1,2,2)\\nplt.plot(t, y, \\'b\\')\\nplt.grid()\\nplt.xlabel(\"Temps $t$\")\\nplt.ylabel(\"Amplitude $x(t)$\")\\n\\nplt.show()\\n'"
#     228       ]
#     229      },
#     230      "execution_count": 9,
#     231      "metadata": {},
#     232      "output_type": "execute_result"
#     233     }
#     234    ],
#     235    "source": [
#     236     "\"\"\"\n",
#     237     "import numpy as np\n",
#     238     "import matplotlib.pyplot as plt\n",
#     239     "\n",
#     240     "# Signal\n",
#     241     "T = 1.\n",
#     242     "\n",
#     243     "def signal(t,f=1): return np.sin(2. *f* np.pi * t / T)\n",
#     244     "\n",
#     245     "# Echantillonnage\n",
#     246     "D = 5. # Duree d'observation\n",
#     247     "fe = 10. # Frequence d'echantillonnage\n",
#     248     "N = int(D * fe) + 1 # Nombre de points enregistres\n",
#     249     "\n",
#     250     "tp = np.linspace(0., D, 1000) # Grille plus fine pour tracer l'allure du signal parfait\n",
#     251     "tp2 = np.linspace(D, D*2, 1000) # Grille plus fine pour tracer l'allure du signal parfait\n",
#     252     "\n",
#     253     "y=np.concatenate((signal(tp),signal(tp2,f=2)))\n",
#     254     "t=np.concatenate((tp,tp2))\n",
#     255     "\n",
#     256     "# Trace du signal\n",
#     257     "\n",
#     258     "fig = plt.figure(figsize=(12, 3))\n",
#     259     "\n",
#     260     "y=np.concatenate((signal(tp),signal(tp2,f=2)))\n",
#     261     "t=np.concatenate((tp,tp2))\n",
#     262     "\n",
#     263     "\n",
#     264     "fig.add_subplot(1,2,1)\n",
#     265     "plt.plot(t, y, 'b')\n",
#     266     "plt.grid()\n",
#     267     "plt.xlabel(\"Temps $t$\")\n",
#     268     "plt.ylabel(\"Amplitude $x(t)$\")\n",
#     269     "\n",
#     270     "\n",
#     271     "y=np.concatenate((signal(tp,f=2),signal(tp2,f=1)))\n",
#     272     "fig.add_subplot(1,2,2)\n",
#     273     "plt.plot(t, y, 'b')\n",
#     274     "plt.grid()\n",
#     275     "plt.xlabel(\"Temps $t$\")\n",
#     276     "plt.ylabel(\"Amplitude $x(t)$\")\n",
#     277     "\n",
#     278     "plt.show()\n",
#     279     "\"\"\"\n"
#     280    ]
#     281   },
#     282   {
#     283    "cell_type": "code",
#     284    "execution_count": 10,
#     285    "id": "f836a8be",
#     286    "metadata": {},
#     287    "outputs": [
#     288     {
#     289      "data": {
#     290       "text/plain": [
#     291        "'\\nimport numpy as np\\nimport matplotlib.pyplot as plt\\n\\n# Signal\\nT = 1.\\n\\ndef signalMorlet(t,f=1): return np.sin(2. *f* np.pi * t / T)*math.e**(-(t**2)/2)\\n\\n# Echantillonnage\\nD = 10. # Duree d\\'observation\\n\\ntp = np.linspace(-D/2, D/2, 1000) # Grille plus fine pour tracer l\\'allure du signal parfait\\n\\ny=signalMorlet(t,f=1)\\n\\n# Trace du signal\\n\\nfig = plt.figure(figsize=(12, 3))\\n\\n\\nfig.add_subplot(1,2,1)\\nplt.plot(tp, signalMorlet(tp), \\'b\\')\\nplt.grid()\\nplt.xlabel(\"Temps $t$\")\\nplt.ylabel(\"Amplitude $x(t)$\")\\n\\n\\nfig.add_subplot(1,2,2)\\n\\nt=[ 0. , 0.5]\\ny=[ 1. , 1.]\\nplt.plot(t, y, \\'b\\')\\nt=[ 0.5 , 1.]\\ny=[ -1. , -1.]\\nplt.plot(t, y, \\'b\\')\\nt=[ 1. , 2.]\\ny=[ 0. , 0.]\\nplt.plot(t, y, \\'b\\')\\nt=[ -1. , 0.]\\ny=[ 0., 0.]\\nplt.plot(t, y, \\'b\\')\\nt=[ 0. , 0.]\\ny=[ 0. , 1.]\\nplt.plot(t, y, \\'b\\')\\nt=[ 1. , 1.]\\ny=[ 0. , -1.]\\nplt.plot(t, y, \\'b\\')\\nt=[ 0.5 , 0.5]\\ny=[ 1. , -1.]\\nplt.plot(t, y, \\'b\\')\\nplt.grid()\\nplt.xlabel(\"Temps $t$\")\\nplt.ylabel(\"Amplitude $x(t)$\")\\n\\nplt.show()\\n'"
#     292       ]
#     293      },
#     294      "execution_count": 10,
#     295      "metadata": {},
#     296      "output_type": "execute_result"
#     297     }
#     298    ],
#     299    "source": [
#     300     "\"\"\"\n",
#     301     "import numpy as np\n",
#     302     "import matplotlib.pyplot as plt\n",
#     303     "\n",
#     304     "# Signal\n",
#     305     "T = 1.\n",
#     306     "\n",
#     307     "def signalMorlet(t,f=1): return np.sin(2. *f* np.pi * t / T)*math.e**(-(t**2)/2)\n",
#     308     "\n",
#     309     "# Echantillonnage\n",
#     310     "D = 10. # Duree d'observation\n",
#     311     "\n",
#     312     "tp = np.linspace(-D/2, D/2, 1000) # Grille plus fine pour tracer l'allure du signal parfait\n",
#     313     "\n",
#     314     "y=signalMorlet(t,f=1)\n",
#     315     "\n",
#     316     "# Trace du signal\n",
#     317     "\n",
#     318     "fig = plt.figure(figsize=(12, 3))\n",
#     319     "\n",
#     320     "\n",
#     321     "fig.add_subplot(1,2,1)\n",
#     322     "plt.plot(tp, signalMorlet(tp), 'b')\n",
#     323     "plt.grid()\n",
#     324     "plt.xlabel(\"Temps $t$\")\n",
#     325     "plt.ylabel(\"Amplitude $x(t)$\")\n",
#     326     "\n",
#     327     "\n",
#     328     "fig.add_subplot(1,2,2)\n",
#     329     "\n",
#     330     "t=[ 0. , 0.5]\n",
#     331     "y=[ 1. , 1.]\n",
#     332     "plt.plot(t, y, 'b')\n",
#     333     "t=[ 0.5 , 1.]\n",
#     334     "y=[ -1. , -1.]\n",
#     335     "plt.plot(t, y, 'b')\n",
#     336     "t=[ 1. , 2.]\n",
#     337     "y=[ 0. , 0.]\n",
#     338     "plt.plot(t, y, 'b')\n",
#     339     "t=[ -1. , 0.]\n",
#     340     "y=[ 0., 0.]\n",
#     341     "plt.plot(t, y, 'b')\n",
#     342     "t=[ 0. , 0.]\n",
#     343     "y=[ 0. , 1.]\n",
#     344     "plt.plot(t, y, 'b')\n",
#     345     "t=[ 1. , 1.]\n",
#     346     "y=[ 0. , -1.]\n",
#     347     "plt.plot(t, y, 'b')\n",
#     348     "t=[ 0.5 , 0.5]\n",
#     349     "y=[ 1. , -1.]\n",
#     350     "plt.plot(t, y, 'b')\n",
#     351     "plt.grid()\n",
#     352     "plt.xlabel(\"Temps $t$\")\n",
#     353     "plt.ylabel(\"Amplitude $x(t)$\")\n",
#     354     "\n",
#     355     "plt.show()\n",
#     356     "\"\"\""
#     357    ]
#     358   }
#     359  ],
#     360  "metadata": {
#     361   "kernelspec": {
#     362    "display_name": "Python 3 (ipykernel)",
#     363    "language": "python",
#     364    "name": "python3"
#     365   },
#     366   "language_info": {
#     367    "codemirror_mode": {
#     368     "name": "ipython",
#     369     "version": 3
#     370    },
#     371    "file_extension": ".py",
#     372    "mimetype": "text/x-python",
#     373    "name": "python",
#     374    "nbconvert_exporter": "python",
#     375    "pygments_lexer": "ipython3",
#     376    "version": "3.11.3"
#     377   }
#     378  },
#     379  "nbformat": 4,
#     380  "nbformat_minor": 5
#     381 }
#
# error: OpenCV(4.7.0) D:\a\opencv-python\opencv-python\opencv\modules\imgproc\src\color.cpp:182: error: (-215:Assertion failed) !_src.empty() in function 'cv::cvtColor'

# %%
def initBlobDetect():
    params = cv2.SimpleBlobDetector_Params()
    
    # Change thresholds
    params.minThreshold = 1
    params.maxThreshold = 500
    
    # Filter by Area.
    params.filterByArea = True
    params.minArea = 500 #700
    params.maxArea = 3000 #3000
    
    # Filter by Circularity
    params.filterByCircularity = True
    params.minCircularity = 0.5
    
    # Filter by Convexity
    params.filterByConvexity = False
    #params.minConvexity = 0.99
    
    # Filter by Inertia
    params.filterByInertia = True
    params.minInertiaRatio = 0.05
    params.maxInertiaRatio = 0.9
    
    params.filterByColor = True
    params.blobColor = 255
    
    params.minDistBetweenBlobs = 30 #30 #10
    
    # Create a detector with the parameters
    ver = (cv2.__version__).split('.')
    if int(ver[0]) < 3 :
        detector = cv2.SimpleBlobDetector(params)
    else : 
        detector = cv2.SimpleBlobDetector_create(params)
        
    return detector

def checkBlob(detector,mask,frame,idx,show=False):# Setup SimpleBlobDetector parameters.
        
    # Detect blobs.
    keypoints = detector.detect(mask)
    
    # Draw detected blobs as red circles.
    # cv2.DRAW_MATCHES_FLAGS_DRAW_RICH_KEYPOINTS ensures the size of the circle corresponds to the size of blob
    N=len(keypoints) 
    pts=[[0,0,0,0]]
    if N > 0:
        for i in range(N):
            
            x=int(keypoints[i].pt[0])
            y=int(keypoints[i].pt[1])
            d=int(keypoints[i].size)
            r=d//2
            
            if y-r>0 and x-r>0 and y+r<frame.shape[0] and x+r<frame.shape[1]: 
                box_cp=frame[y-r:y+r,x-r:x+r,:]
                sumGreen=selectGreenHSV(box_cp)
                
                display(box_cp,name="box blob")
                
                cv2.circle(frame,(x,y),1,(0,0,255),d)
                
                if sumGreen>1500:
                    #print("blob green:",sumGreen)
                    b=[x,y,idx,0.25]
                    pts=np.append(pts,[b],axis=0) 
                    cv2.rectangle(frame,(x-r+5,y-r+5),(x+r-5,y+r-5),(255,0,0),-1)
                
                
    #frame_with_keypoints = cv2.drawKeypoints(frame, keypoints, np.array([]), (0,0,255), cv2.DRAW_MATCHES_FLAGS_DRAW_RICH_KEYPOINTS)
    
    if show:
        display(frame,name='detect blob')
        
    if len(pts)>1:
        pts=pts[1:]
        return pts
    else:
        return None
 
    
######################################################################################################

def checkBoxes(frame_diff, boundingBoxes ,show=False,coeff=150,wave_temp=None,wave_temp2=None):
    """ select the ball among all the objects by using the wavelet transform

    Args:
        frame_diff (array): _description_
        boundingBoxes (list): boxes of all the objects
        show (bool, optional): to see the boxe selected if any. Defaults to False.
        coeff (int, optional): coeff of similitude maximum allowed. Defaults to 150.
        wave_temp (array, optional): wavelet transform of the template. Defaults to None.
        wave_temp2 (array, optional): wavelet transform of the black template. Defaults to None.

    Returns:
        array: best box
    """
    
    if wave_temp is None:
        print("error no template checkBoxes ")
        return None
    if wave_temp2 is None:
        wave_temp2=wave_temp
    
    # we don't consider boxes that are too small or too big
    size_min=32
    size_max=wave_temp.shape[0]*3
    
    maxBox=None 
    maxGreen=-1
    maxDiff=-1
    #totH=0    

    L=len(boundingBoxes)
    
    for box in boundingBoxes:

        if box[3]>size_min and box[3]<size_max and box[2]>size_min and box[2]<size_max and box[2]/box[3]<100 and box[2]/box[3]>0.001:

            box_cp = frame_diff[box[1]:(box[1]+box[3]),box[0]:(box[0]+box[2]),:]
                       
            #temp_hist0 = cv2.calcHist(box_cp, [0], None,[256],[0,256] )
            #temp_hist1 = cv2.calcHist(box_cp, [1], None,[256],[0,256] )
            #temp_hist2 = cv2.calcHist(box_cp, [2], None,[256],[0,256] )
            #tot_histogramm=np.sum(temp_hist0[120:130]+temp_hist1[120:130]+temp_hist2[120:130])
            
            wave_box=Wavelet(box_cp)

            diff1=cv2.absdiff(wave_temp[:2,:2,:2],wave_box[:2,:2,:2])#cv2.absdiff(wave_temp[0,0,:],wave_box[0,0,:])+cv2.absdiff(wave_temp[1,1,:],wave_box[1,1,:])
            diff2=cv2.absdiff(wave_temp2[:2,:2,:2],wave_box[:2,:2,:2])#cv2.absdiff(wave_temp2[0,0,:],wave_box[0,0,:])+cv2.absdiff(wave_temp2[1,1,:],wave_box[1,1,:])
            diff=min(np.sum(diff1),np.sum(diff2))
        
            diff=np.sum(diff)
            
            """
            sumGreen=selectGreenHSV(box_cp)
            
            if sumGreen<0.000000001:
                sumGreen=0.000000001
            """
            
            diff_weight=( diff/3 ) # +( 1000 / sumGreen)#+tot_histogramm
            
            if diff_weight is not None and coeff>diff_weight:
                coeff = diff_weight
                maxBox = box
                #maxGreen = sumGreen
                maxDiff = diff/3
                
            if L==1 and diff_weight<coeff+10:
                coeff=diff_weight
                maxBox=box

    if maxBox is None:
        return None
    
    print("coeff box and green: ",maxDiff ," => ",coeff )
    
    #if show:
    #    box_cp= frame_diff[maxBox[1]:(maxBox[1]+maxBox[3]),maxBox[0]:(maxBox[0]+maxBox[2]),:]   
    #    cv2.rectangle(frame_diff, (int(box[0]), int(box[1])),(int(box[0]+box[2]), int(box[1]+box[3])), (255,255,255), 2)        
    #    display(frame_diff,name='select box')
        
    return maxBox
